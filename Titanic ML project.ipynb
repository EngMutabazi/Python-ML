# %% [markdown]
# # Python programming + Data set

# %% [markdown]
# ##  importing packages

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load the titanic dataset from the seaborn package

# %%
data=sbn.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ##  Check the data type of the column.

# %%
data.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# ## Get the length of the columns

# %%
len(data_clean.columns)
# Out:
# 15

# %% [markdown]
# ## Get the length of the data set

# %%
len(data)
# Out:
# 891

# %% [markdown]
# ## To show the statistical summary of the data set

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Count the number of missing values in column

# %%
no_miss_value=data.isna().sum()
no_miss_value
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Total number of null values in the dataset

# %%
tot_miss_value=data.isna().sum().sum()
tot_miss_value
# Out:
# 869

# %% [markdown]
# ## Clean the dataset by by removing every record that contain a missing value

# %%
data_clean=data.dropna(axis=0)
data_clean.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## What is the size of cleaned data

# %%
print("The size of cleaned data is:",data_clean.size)
# Out:
# The size of cleaned data is: 2730

# %% [markdown]
# ## Count number of rows and columns for cleaned data

# %%
count_row = data_clean.shape[0]  
count_col = data_clean.shape[1]

# %%
print("number of rows:",count_row)
# Out:
# number of rows: 182

# %%
print("number of rows:",count_col)
# Out:
# number of rows: 15

# %% [markdown]
# ## Show the dimension of the dataset(data frame)

# %%
data_clean.shape
# Out:
# (182, 15)

# %% [markdown]
# ##  Count the number of survived females

# %%
saviv_femele=data_clean[(data_clean['sex'].str.match('female')) & (data_clean['survived'] == 1)]
print('The number of survived femele is:',len(saviv_femele))
# Out:
# The number of survived femele is: 82

# %% [markdown]
# OR

# %%
sav_fem=data_clean[(data_clean.sex=='female') & (data_clean['survived']==1)]
print('The number of survived femele is:',len(sav_fem))
# Out:
# The number of survived femele is: 82

# %% [markdown]
# ## Count the number of survived male

# %%
surv_male=data_clean[(data_clean.sex=='male') & (data_clean['survived']==1)]
print('The number of survived male=',len(surv_male))
# Out:
# The number of survived male= 41

# %% [markdown]
# ##  Compute the average of males who did not survived

# %%
not_surv_male=data_clean[(data_clean.sex=='male')&(data_clean['survived']==0)]
len(not_surv_male)
# Out:
# 53

# %%
not_surv_male['age'].mean()
# Out:
# 42.84905660377358

# %% [markdown]
# OR

# %%
not_sviv_male=data_clean[np.logical_and(data_clean.sex=='male',data_clean['survived']==0 )]

# %%
not_sviv_male
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 27          0       1  male  19.0      3      2  263.0000        S   First
# 54          0       1  male  65.0      0      1   61.9792        C   First
# 62          0       1  male  45.0      1      0   83.4750        S   First
# 75          0       3  male  25.0      0      0    7.6500        S   Third
# 92          0       1  male  46.0      1      0   61.1750        S   First
# 96          0       1  male  71.0      0      0   34.6542        C   First
# 102         0       1  male  21.0      0      1   77.2875        S   First
# 110         0       1  male  47.0      0      0   52.0000        S   First
# 118         0       1  male  24.0      0      1  247.5208        C   First
# 124         0       1  male  54.0      0      1   77.2875        S   First
# ...

# %%
not_sviv_male['age'].mean()
# Out:
# 42.84905660377358

# %% [markdown]
# ##  Group the data frame by values in Survived column, and count the number of occurrences of each group.

# %%
survived_count = data_clean.groupby('survived')['survived'].count()
survived_count
# Out:
# survived
# 0     59
# 1    123
# Name: survived, dtype: int64

# %%
plt.figure(figsize=(4,5))
plt.bar(survived_count.index,survived_count.values)
plt.title("Grouped by survivals")
plt.xticks([0,1],['not survived','survived'])
for i, value in enumerate(survived_count.values):
    plt.text(i, value-5, str(value), fontsize=12, color='white',
             horizontalalignment='center', verticalalignment='center')
plt.show()

# %% [markdown]
# ##  Group the data frame by classes in the pclass column, and count the number of occurrences of each group.

# %%
group_pclass=data_clean.groupby('pclass')['pclass'].count()

# %%
group_pclass
# Out:
# pclass
# 1    157
# 2     15
# 3     10
# Name: pclass, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.title('Grouped by pclass')
plt.pie(group_pclass.values, labels=['Class 1', 'Class 2', 'Class 3'], 
 autopct='%1.1f%%', textprops={'fontsize':13})
plt.show()

# %%
group_sex_mf=data_clean.groupby('sex')['sex'].count()

# %%
group_sex_mf
# Out:
# sex
# female    88
# male      94
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(7,9))
plt.title('grouped by gender')
plt.pie(group_sex_mf.values,labels=['female','male'], autopct='%1.1f%%', textprops={'fontsize':10})
plt.show()

# %% [markdown]
# ## Display total  number Survivial  according to gender

# %%
gender_survived=data_clean.groupby('sex')['survived'].sum()
gender_survived
# Out:
# sex
# female    82
# male      41
# Name: survived, dtype: int64

# %%
plt.figure(figsize=(4,5))
plt.title('Survived female and male')
plt.bar(gender_survived.index,gender_survived.values)
for i,value in enumerate(gender_survived.values):
    plt.text(i,value-20,str(value),fontsize=10,
             color='white',
             horizontalalignment='center', verticalalignment='center')

# %% [markdown]
# ## Here we see the survival rate across all the classes

# %%
x=data_clean.groupby(['pclass', 'survived', 'sex'])
x.size()
# Out:
# pclass  survived  sex
# 1       0         female     3
#                   male      48
#         1         female    71
#                   male      35
# 2       0         female     1
#                   male       2
#         1         female     8
#                   male       4
# 3       0         female     2
#                   male       3
#         1         female     3
#                   male       2
# dtype: int64
